# %% [markdown]
# # Flight Data Analysis

# %% [markdown]
# dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
# dataset = pd.read_excel(r"D:\Downloads File\pandas practise file\EDA_PRACTISE_SET\flight_price.xlsx")

dataset = pd.read_excel(r"D:\Python Project\Flight_data_analysis\data\flight_price.xlsx")

# %%
df = dataset.copy()

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df.shape
# Out:
# (10683, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
# drop null rows
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 220

# %%
# Checking duplicated values
df[df.duplicated()]
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 683    Jet Airways       1/06/2019     Delhi      Cochin
# 1061     Air India      21/05/2019     Delhi      Cochin
# 1348     Air India      18/05/2019     Delhi      Cochin
# 1418   Jet Airways       6/06/2019     Delhi      Cochin
# 1674        IndiGo      24/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10594  Jet Airways      27/06/2019     Delhi      Cochin
# 10616  Jet Airways       1/06/2019     Delhi      Cochin
# 10634  Jet Airways       6/06/2019     Delhi      Cochin
# 10672  Jet Airways      27/06/2019     Delhi      Cochin
# 10673  Jet Airways      27/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 683    DEL → NAG → BOM → COK    14:35  04:25 02 Jun  13h 50m     2 stops
# 1061   DEL → GOI → BOM → COK    22:00  19:15 22 May  21h 15m     2 stops
# ...

# %%
df.duplicated(subset=df.columns.drop('Price')).sum()
# Out:
# 419

# %% [markdown]
# No need to drop duplicate because price is variate

# %%
# Checking Unique Values
cat_col = df.select_dtypes(include='object').columns
for col in cat_col:
    print(f"{col} : {df[col].unique()}")
# Out:
# Airline : ['IndiGo' 'Air India' 'Jet Airways' 'SpiceJet' 'Multiple carriers' 'GoAir'
#  'Vistara' 'Air Asia' 'Vistara Premium economy' 'Jet Airways Business'
#  'Multiple carriers Premium economy' 'Trujet']
# Date_of_Journey : ['24/03/2019' '1/05/2019' '9/06/2019' '12/05/2019' '01/03/2019'
#  '24/06/2019' '12/03/2019' '27/05/2019' '1/06/2019' '18/04/2019'
#  '9/05/2019' '24/04/2019' '3/03/2019' '15/04/2019' '12/06/2019'
#  '6/03/2019' '21/03/2019' '3/04/2019' '6/05/2019' '15/05/2019'
#  '18/06/2019' '15/06/2019' '6/04/2019' '18/05/2019' '27/06/2019'
#  '21/05/2019' '06/03/2019' '3/06/2019' '15/03/2019' '3/05/2019'
#  '9/03/2019' '6/06/2019' '24/05/2019' '09/03/2019' '1/04/2019'
#  '21/04/2019' '21/06/2019' '27/03/2019' '18/03/2019' '12/04/2019'
#  '9/04/2019' '1/03/2019' '03/03/2019' '27/04/2019']
# Source : ['Banglore' 'Kolkata' 'Delhi' 'Chennai' 'Mumbai']
# Destination : ['New Delhi' 'Banglore' 'Cochin' 'Kolkata' 'Delhi' 'Hyderabad']
# ...

# %% [markdown]
# **Date of Journey Editing**

# %%
df['Date_of_Journey'] = pd.to_datetime(df['Date_of_Journey'], format='%d/%m/%Y')

# %%
df['Date_of_Journey']
# Out:
# 0       2019-03-24
# 1       2019-05-01
# 2       2019-06-09
# 3       2019-05-12
# 4       2019-03-01
#            ...
# 10678   2019-04-09
# 10679   2019-04-27
# 10680   2019-04-27
# 10681   2019-03-01
# 10682   2019-05-09
# Name: Date_of_Journey, Length: 10682, dtype: datetime64[ns]

# %%
# For ML
df['Journey_day'] = df['Date_of_Journey'].dt.day
df['Journey_month'] = df['Date_of_Journey'].dt.month
df['Journey_weekday'] = df['Date_of_Journey'].dt.weekday

# Drop the date of journey column as we have extracted day, month and weekday
# df.drop('Date_of_Journey', axis=1, inplace=True)

# %%
df['Journey_day'].unique()
# Out:
# array([24,  1,  9, 12, 27, 18,  3, 15,  6, 21])

# %% [markdown]
# **Depterature Time Editing**

# %%
# df['Dep_Time'] = pd.to_datetime(df['Dep_Time'], format='%H:%M').dt.time  # I give only time output

# %%
# df['Dep_min'].unique()

# %%
# For ML
df['Dep_Time'] = pd.to_datetime(df['Dep_Time'])   # It give date and time output

df['Dep_hour'] = df['Dep_Time'].dt.hour
df['Dep_min'] = df['Dep_Time'].dt.minute

# Drop the departure time column as we have extracted hour and minute
# df.drop('Dep_Time', axis=1, inplace=True)

# %%
df['Dep_hour']
# Out:
# 0        22
# 1         5
# 2         9
# 3        18
# 4        16
#          ..
# 10678    19
# 10679    20
# 10680     8
# 10681    11
# 10682    10
# Name: Dep_hour, Length: 10682, dtype: int32

# %% [markdown]
# **Arrival Time Editing**

# %%
df['Arrival_Time'].unique()
# Out:
# array(['01:10 22 Mar', '13:15', '04:25 10 Jun', ..., '06:50 10 Mar',
#        '00:05 19 Mar', '21:20 13 Mar'], dtype=object)

# %%
df[['Arr_Time', 'Arr_Date']] = df['Arrival_Time'].str.split(' ', n=1, expand=True)

# %%
df['Arrival_hour'] = pd.to_datetime(df['Arr_Time']).dt.hour
df['Arrival_min'] = pd.to_datetime(df['Arr_Time']).dt.minute

# %%
# Jaha Arr_Date available hai → use karo
df['Arr_Date'] = df['Arr_Date'].fillna('')

# Combine karne ke liye year add karna padega
df['Arrival_Date'] = df.apply(
    lambda row: 
    pd.to_datetime(row['Arr_Date'] + ' 2019', format='%d %b %Y')
    if row['Arr_Date'] != '' 
    else row['Date_of_Journey'],
    axis=1
)

# %%
df['Arrival_Date'].unique()
# Out:
# <DatetimeArray>
# ['2019-03-22 00:00:00', '2019-05-01 00:00:00', '2019-06-10 00:00:00',
#  '2019-05-12 00:00:00', '2019-03-01 00:00:00', '2019-06-24 00:00:00',
#  '2019-03-13 00:00:00', '2019-03-02 00:00:00', '2019-05-27 00:00:00',
#  '2019-06-01 00:00:00', '2019-04-18 00:00:00', '2019-05-10 00:00:00',
#  '2019-04-24 00:00:00', '2019-03-04 00:00:00', '2019-04-15 00:00:00',
#  '2019-06-13 00:00:00', '2019-05-28 00:00:00', '2019-03-06 00:00:00',
#  '2019-03-19 00:00:00', '2019-04-03 00:00:00', '2019-05-07 00:00:00',
#  '2019-06-02 00:00:00', '2019-05-15 00:00:00', '2019-06-18 00:00:00',
#  '2019-06-15 00:00:00', '2019-04-06 00:00:00', '2019-06-16 00:00:00',
#  '2019-05-18 00:00:00', '2019-06-27 00:00:00', '2019-05-21 00:00:00',
#  '2019-06-03 00:00:00', '2019-03-15 00:00:00', '2019-05-19 00:00:00',
#  '2019-05-06 00:00:00', '2019-03-21 00:00:00', '2019-03-24 00:00:00',
#  '2019-05-03 00:00:00', '2019-05-16 00:00:00', '2019-06-28 00:00:00',
# ...

# %%
df['Arrival_Day'] = df['Arrival_Date'].dt.day

# %%
df['Journey_Diff_Days'] = (df['Arrival_Date'] - df['Date_of_Journey']).dt.days

# %% [markdown]
# **Duration Editing**

# %%
df['Duration'].unique()
# Out:
# array(['2h 50m', '7h 25m', '19h', '5h 25m', '4h 45m', '2h 25m', '15h 30m',
#        '21h 5m', '25h 30m', '7h 50m', '13h 15m', '2h 35m', '2h 15m',
#        '12h 10m', '26h 35m', '4h 30m', '22h 35m', '23h', '20h 35m',
#        '5h 10m', '15h 20m', '2h 55m', '13h 20m', '15h 10m', '5h 45m',
#        '5h 55m', '13h 25m', '22h', '5h 30m', '10h 25m', '5h 15m',
#        '2h 30m', '6h 15m', '11h 55m', '11h 5m', '8h 30m', '22h 5m',
#        '2h 45m', '12h', '16h 5m', '19h 55m', '3h 15m', '25h 20m', '3h',
#        '16h 15m', '15h 5m', '6h 30m', '25h 5m', '12h 25m', '27h 20m',
#        '10h 15m', '10h 30m', '1h 30m', '1h 25m', '26h 30m', '7h 20m',
#        '13h 30m', '5h', '19h 5m', '14h 50m', '2h 40m', '22h 10m',
#        '9h 35m', '10h', '21h 20m', '18h 45m', '12h 20m', '18h', '9h 15m',
#        '17h 30m', '16h 35m', '12h 15m', '7h 30m', '24h', '8h 55m',
#        '7h 10m', '14h 30m', '30h 20m', '15h', '12h 45m', '10h 10m',
#        '15h 25m', '14h 5m', '20h 15m', '23h 10m', '18h 10m', '16h',
# ...

# %%
df['Duration'].isna().sum()
# Out:
# 0

# %%
df['Duration'].str.extract('(\d+)m').isna().sum()
# Out:
# 0    1031
# dtype: int64

# %%
df['Duration_hours'] = df['Duration'].str.extract('(\d+)h').fillna(0).astype(int)
df['Duration_minutes'] = df['Duration'].str.extract('(\d+)m').fillna(0).astype(int)

# %%
# Missing minutes filling
df['Duration'] = df['Duration'].apply(
    lambda x: x if 'm' in x else x + ' 0m'
)

# %%
# yeha nan value fill with zero and extract hour and minute
df['Duration_hours'] = df['Duration'].str.extract('(\d+)h').astype(float)
df['Duration_minutes'] = df['Duration'].str.extract('(\d+)m').astype(int)

# %%
df['Duration_hours']
df['Duration_minutes']
# Out:
# 0        50
# 1        25
# 2         0
# 3        25
# 4        45
#          ..
# 10678    30
# 10679    35
# 10680     0
# 10681    40
# 10682    20
# Name: Duration_minutes, Length: 10682, dtype: int32

# %%
# Calculating total duration in minutes
df['Duration_total_mins'] = df['Duration_hours']*60 + df['Duration_minutes']

# %%
df['Duration_total_mins']
# Out:
# 0         170.0
# 1         445.0
# 2        1140.0
# 3         325.0
# 4         285.0
#           ...
# 10678     150.0
# 10679     155.0
# 10680     180.0
# 10681     160.0
# 10682     500.0
# Name: Duration_total_mins, Length: 10682, dtype: float64

# %% [markdown]
# **Total Stops Editing**

# %%
df['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %%
df['Total_Stops'] = df['Total_Stops'].map({
    'non-stop': 0,
    '1 stop': 1,
    '2 stops': 2,
    '3 stops': 3,
    '4 stops': 4
})

# %%
df['Total_Stops'].isna().sum()
# Out:
# 0

# %%
df['Total_Stops'].unique()
# Out:
# array([0, 2, 1, 3, 4], dtype=int64)

# %% [markdown]
# **Additional Info Editing**

# %%
df['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
df['Additional_Info'].isna().sum()
# Out:
# 0

# %%
df['Additional_Info'] = df['Additional_Info'].str.lower()

# %%
df['Additional_Info'].value_counts()
# Out:
# Additional_Info
# no info                         8347
# in-flight meal not included     1982
# no check-in baggage included     320
# 1 long layover                    19
# change airports                    7
# business class                     4
# 1 short layover                    1
# red-eye flight                     1
# 2 long layover                     1
# Name: count, dtype: int64

# %%
# For ML
df['Additional_Info'] = df['Additional_Info'].str.lower()

df['Additional_Info_flag'] = df['Additional_Info'].apply(
    lambda x: 0 if x == 'no info' else 1
)

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price', 'Journey_day', 'Journey_month',
#        'Journey_weekday', 'Dep_hour', 'Dep_min', 'Arr_Time', 'Arr_Date',
#        'Arrival_hour', 'Arrival_min', 'Arrival_Date', 'Arrival_Day',
#        'Journey_Diff_Days', 'Duration_hours', 'Duration_minutes',
#        'Duration_total_mins', 'Additional_Info_flag'],
#       dtype='object')

# %% [markdown]
# ##### Drop the date columns

# %%
df.drop(columns=['Date_of_Journey', 'Dep_Time', 'Arrival_Time', 'Arr_Time', 'Arr_Date', 'Duration', 'Additional_Info'], inplace=True)

# %%
df.drop('Arrival_Date', axis=1, inplace=True)

# %%
df.drop('Route',axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10682 entries, 0 to 10682
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Airline               10682 non-null  object
#  1   Source                10682 non-null  object
#  2   Destination           10682 non-null  object
#  3   Total_Stops           10682 non-null  int64
#  4   Price                 10682 non-null  int64
#  5   Journey_day           10682 non-null  int32
#  6   Journey_month         10682 non-null  int32
#  7   Journey_weekday       10682 non-null  int32
#  8   Dep_hour              10682 non-null  int32
#  9   Dep_min               10682 non-null  int32
#  10  Arrival_hour          10682 non-null  int32
#  11  Arrival_min           10682 non-null  int32
#  12  Arrival_Day           10682 non-null  int32
#  13  Journey_Diff_Days     10682 non-null  int64
#  14  Duration_hours        10681 non-null  float64
# ...

# %%
df.fillna(0, inplace=True)

# %%
# Save cleaned data
# df.to_csv('cleaned_flight_data.csv', index=False)

# %%
df.describe()
# Out:
#         Total_Stops         Price   Journey_day  Journey_month  \
# count  10682.000000  10682.000000  10682.000000   10682.000000
# mean       0.824190   9087.214567     13.509081       4.708575
# std        0.675229   4611.548810      8.479363       1.164408
# min        0.000000   1759.000000      1.000000       3.000000
# 25%        0.000000   5277.000000      6.000000       3.000000
# 50%        1.000000   8372.000000     12.000000       5.000000
# 75%        1.000000  12373.000000     21.000000       6.000000
# max        4.000000  79512.000000     27.000000       6.000000
#
#        Journey_weekday      Dep_hour       Dep_min  Arrival_hour  \
# count     10682.000000  10682.000000  10682.000000  10682.000000
# mean          2.935125     12.491013     24.409287     13.349186
# std           2.006591      5.748820     18.767801      6.859317
# min           0.000000      0.000000      0.000000      0.000000
# 25%           1.000000      8.000000      5.000000      8.000000
# ...

# %% [markdown]
# ### Without Pipeline

# %% [markdown]
# ##### **Train Test Split**

# %%
from sklearn.model_selection import train_test_split
x = df.drop('Price', axis=1)
y = df['Price']

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
# OneHotEncoding for categorical variables
cat_col = x_train.select_dtypes(include='object').columns
x_train = pd.get_dummies(x_train, columns=cat_col, drop_first=True)
x_test = pd.get_dummies(x_test, columns=cat_col, drop_first=True)

# Ensure x_train and x_test have the same columns
x_train, x_test = x_train.align(x_test, join='left', axis=1, fill_value=0)

# %%
x_train.shape, x_test.shape
# Out:
# ((8545, 34), (2137, 34))

# %% [markdown]
# ##### RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

rf_model = RandomForestRegressor(n_estimators=160, max_depth=20, random_state=42)
rf_model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_depth=20, n_estimators=160, random_state=42)

# %%
# Make predictions
rf_pred = rf_model.predict(x_test)

# Evaluate the model
mae = mean_absolute_error(y_test, rf_pred)
mse = mean_squared_error(y_test, rf_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, rf_pred)

print(f"Mean Absolute Error: {mae}")
print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {rmse}")
print(f"R² Score: {r2}")
# Out:
# Mean Absolute Error: 623.6477460371635
# Mean Squared Error: 2083919.0642273894
# Root Mean Squared Error: 1443.5785618480863
# R² Score: 0.9033524895354154

# %% [markdown]
# ##### XGBOOST

# %%
from xgboost import XGBRegressor

# build and train XGBoost
xgb = XGBRegressor(
    n_estimators=200,
    max_depth=8,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1,
    tree_method="hist"  # fast on moderate datasets
)
xgb.fit(x_train, y_train)

# 6) predict, evaluate
xgb_pred = xgb.predict(x_test)
mae = mean_absolute_error(y_test, xgb_pred)
mse = mean_squared_error(y_test, xgb_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, xgb_pred)

print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2:", r2)
# Out:
# MAE: 677.7969360351562
# MSE: 1864602.125
# RMSE: 1365.5043482171707
# R2: 0.9135239124298096

# %% [markdown]
# ##### LightGBM

# %%
# pip install lightgbm
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.  Using cached lightgbm-4.6.0-py3-none-win_amd64.whl.metadata (17 kB)
#
# ...
# Using cached lightgbm-4.6.0-py3-none-win_amd64.whl (1.5 MB)
# ...

# %%
from lightgbm import LGBMRegressor

lgb_model =LGBMRegressor(
        n_estimators=200,
        learning_rate=0.1,
        max_depth=12,
        random_state=42)

lgb_model.fit(x_train, y_train)

lgb_pred = lgb_model.predict(x_test)
mae = mean_absolute_error(y_test, lgb_pred)
mse = mean_squared_error(y_test, lgb_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, lgb_pred)

print("MAE:", mae)
print("MSE:", mse)
print("RMSE:", rmse)
print("R2:", r2)
# Out:
# MAE: 810.8915145164303
# MSE: 2204812.8628940973
# RMSE: 1484.8612268135016
# R2: 0.8977457052450303

# %% [markdown]
# ##### Pipeline Process

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.impute import SimpleImputer
# from sklearn.ensemble import RandomForestRegressor
# from xgboost import XGBRegressor

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10682 entries, 0 to 10682
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Airline               10682 non-null  object
#  1   Source                10682 non-null  object
#  2   Destination           10682 non-null  object
#  3   Total_Stops           10682 non-null  int64
#  4   Journey_day           10682 non-null  int32
#  5   Journey_month         10682 non-null  int32
#  6   Journey_weekday       10682 non-null  int32
#  7   Dep_hour              10682 non-null  int32
#  8   Dep_min               10682 non-null  int32
#  9   Arrival_hour          10682 non-null  int32
#  10  Arrival_min           10682 non-null  int32
#  11  Arrival_Day           10682 non-null  int32
#  12  Journey_Diff_Days     10682 non-null  int64
#  13  Duration_hours        10682 non-null  float64
#  14  Duration_minutes      10682 non-null  int32
# ...

# %%
# Train Test Split
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8545 entries, 10005 to 7270
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Airline               8545 non-null   object
#  1   Source                8545 non-null   object
#  2   Destination           8545 non-null   object
#  3   Total_Stops           8545 non-null   int64
#  4   Journey_day           8545 non-null   int32
#  5   Journey_month         8545 non-null   int32
#  6   Journey_weekday       8545 non-null   int32
#  7   Dep_hour              8545 non-null   int32
#  8   Dep_min               8545 non-null   int32
#  9   Arrival_hour          8545 non-null   int32
#  10  Arrival_min           8545 non-null   int32
#  11  Arrival_Day           8545 non-null   int32
#  12  Journey_Diff_Days     8545 non-null   int64
#  13  Duration_hours        8545 non-null   float64
#  14  Duration_minutes      8545 non-null   int32
# ...

# %%
# 2. PREPROCESSING PIPELINE
# =====================================================
# Identify numeric and categorical columns
numeric_features = X_train.select_dtypes(include=["int64", "float64","int32"]).columns.tolist()
categorical_features = X_train.select_dtypes(include=["object"]).columns.tolist()

# Create preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_features),
        ("cat", OneHotEncoder(drop="first", sparse_output=False, handle_unknown='ignore'), categorical_features),
         ]
)

# %%
# =====================================================
# 3. RANDOM FOREST PIPELINE
# =====================================================
rf_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("model", RandomForestRegressor(n_estimators=160, max_depth=20, random_state=42))
])

rf_pipeline.fit(X_train, Y_train)
rf_pipe_pred = rf_pipeline.predict(X_test)

print("=== RANDOM FOREST WITH PIPELINE ===")
print(f"MAE: {mean_absolute_error(Y_test, rf_pipe_pred):.2f}")
print(f"RMSE: {np.sqrt(mean_squared_error(Y_test, rf_pipe_pred)):.2f}")
print(f"R²: {r2_score(Y_test, rf_pipe_pred):.4f}\n")
# Out:
# === RANDOM FOREST WITH PIPELINE ===
# MAE: 623.88
# RMSE: 1443.59
# R²: 0.9034

# %%
# =====================================================
# 4. XGBOOST PIPELINE
# =====================================================
xgb_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("model", XGBRegressor(
        n_estimators=200,
        max_depth=8,
        learning_rate=0.1,
        subsample=0.8,
        random_state=42,
        tree_method="hist"
    ))
])

xgb_pipeline.fit(X_train, Y_train)
xgb_pred = xgb_pipeline.predict(X_test)

print("=== XGBOOST WITH PIPELINE ===")
print(f"MAE: {mean_absolute_error(Y_test, xgb_pred):.2f}")
print(f"RMSE: {np.sqrt(mean_squared_error(Y_test, xgb_pred)):.2f}")
print(f"R²: {r2_score(Y_test, xgb_pred):.4f}\n")
# Out:
# === XGBOOST WITH PIPELINE ===
# MAE: 665.69
# RMSE: 1329.24
# R²: 0.9181

# %%
# =====================================================
# 5. LIGHTGBM PIPELINE
# =====================================================
lgb_pipeline = Pipeline([
    ("preprocessor", preprocessor),
    ("model", LGBMRegressor(
        n_estimators=200,
        max_depth=12,
        learning_rate=0.1,
        random_state=42,
        n_jobs=-1,
        verbose=-1
    ))
])

lgb_pipeline.fit(X_train, Y_train)
lgb_pred = lgb_pipeline.predict(X_test)

print("=== LIGHTGBM WITH PIPELINE ===")
print(f"MAE: {mean_absolute_error(Y_test, lgb_pred):.2f}")
print(f"RMSE: {np.sqrt(mean_squared_error(Y_test, lgb_pred)):.2f}")
print(f"R²: {r2_score(Y_test, lgb_pred):.4f}\n")
# Out:
# === LIGHTGBM WITH PIPELINE ===
# MAE: 809.80
# RMSE: 1470.03
# R²: 0.8998

# %% [markdown]
# ##### Cross Validation

# %%
# =====================================================
# 6. CROSS-VALIDATION WITH PIPELINE
# =====================================================
print("=== CROSS-VALIDATION SCORES ===")
rf_cv = cross_val_score(rf_pipeline, X_train, Y_train, cv=5, scoring="r2")
print(f"Random Forest CV R² (mean ± std): {rf_cv.mean():.4f} ± {rf_cv.std():.4f}")

xgb_cv = cross_val_score(xgb_pipeline, X_train, Y_train, cv=5, scoring="r2")
print(f"XGBoost CV R² (mean ± std): {xgb_cv.mean():.4f} ± {xgb_cv.std():.4f}")

lgb_cv = cross_val_score(lgb_pipeline, X_train, Y_train, cv=5, scoring="r2")
print(f"LightGBM CV R² (mean ± std): {lgb_cv.mean():.4f} ± {lgb_cv.std():.4f}\n")
# Out:
# === CROSS-VALIDATION SCORES ===
# Random Forest CV R² (mean ± std): 0.8850 ± 0.0134
# XGBoost CV R² (mean ± std): 0.8971 ± 0.0198
# LightGBM CV R² (mean ± std): 0.8592 ± 0.0350

# %% [markdown]
# ##### Hyperparameter Tunning

# %%
# =====================================================
# 7. HYPERPARAMETER TUNING WITH PIPELINE
# =====================================================
param_grid = {
    "model__n_estimators": [50, 100, 200],
    "model__max_depth": [5, 7, 10],
    "model__learning_rate": [0.05, 0.1]
}

grid_search = GridSearchCV(
    xgb_pipeline,
    param_grid,
    cv=3,
    scoring="r2",
    n_jobs=-1
)

grid_search.fit(X_train, Y_train)

print("=== GRID SEARCH RESULTS ===")
print(f"Best Parameters: {grid_search.best_params_}")
print(f"Best CV Score: {grid_search.best_score_:.4f}")

best_pred = grid_search.predict(X_test)
print(f"Test R²: {r2_score(Y_test, best_pred):.4f}\n")
# Out:
# === GRID SEARCH RESULTS ===
# Best Parameters: {'model__learning_rate': 0.05, 'model__max_depth': 10, 'model__n_estimators': 200}
# Best CV Score: 0.8853
# Test R²: 0.9135

# %% [markdown]
# **As we can see clearly that after hyperparamter tunning the R square values get improve a little bit.**

# %% [markdown]
# ##### Save/Drop the Model

# %%
# =====================================================
# 8. SAVE PIPELINE
# =====================================================
import joblib
joblib.dump(xgb_pipeline, "xgb_pipeline_model.pkl")
print("✓ Pipeline saved as 'xgb_pipeline_model.pkl'")
# Out:
# ✓ Pipeline saved as 'xgb_pipeline_model.pkl'

# %% [markdown]
# ##### Checking new data on model

# %%
new_data = pd.DataFrame({
    'Airline': ['IndiGo'],
    'Source': ['Delhi'],
    'Destination': ['Cochin'],
    'Total_Stops': [1],
    'Journey_day': [10],
    'Journey_month': [6],
    'Journey_weekday': [2],
    'Dep_hour': [14],
    'Dep_min': [30],
    'Arrival_hour': [18],
    'Arrival_min': [45],
    'Arrival_Day': [10],
    'Journey_Diff_Days': [0],
    'Duration_hours': [4],
    'Duration_minutes': [15],
    'Duration_total_mins': [255],
    'Additional_Info_flag': [0]
})

# %%
new_data = new_data[X_train.columns]  # It confirm that new_data has same columns as X_train and in same order, filling missing columns with 0 if any

# %%
prediction = xgb_pipeline.predict(new_data)

print("Predicted Price:", prediction[0])
# Out:
# Predicted Price: 5566.0864

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8545 entries, 10005 to 7270
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Airline               8545 non-null   object
#  1   Source                8545 non-null   object
#  2   Destination           8545 non-null   object
#  3   Total_Stops           8545 non-null   int64
#  4   Journey_day           8545 non-null   int32
#  5   Journey_month         8545 non-null   int32
#  6   Journey_weekday       8545 non-null   int32
#  7   Dep_hour              8545 non-null   int32
#  8   Dep_min               8545 non-null   int32
#  9   Arrival_hour          8545 non-null   int32
#  10  Arrival_min           8545 non-null   int32
#  11  Arrival_Day           8545 non-null   int32
#  12  Journey_Diff_Days     8545 non-null   int64
#  13  Duration_hours        8545 non-null   float64
#  14  Duration_minutes      8545 non-null   int32
# ...
